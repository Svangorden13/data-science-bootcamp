# %%
class student:
    pass

# %%
s1 = student()

# %%
s1.fname = "Zia A"
s1.lname = "Khan"

# %%
s1.__dict__
# Out:
# {'name': 'Zia', 'fname': 'Zia A', 'lname': 'Khan'}

# %%
s3 = student("Ali","Akbar")

# %%
s3.__dict__
# Out:
# {'first': 'Ali', 'last': 'Akbar', 'email': 'Ali.Akbar@lf.com'}

# %%
u1 = {'name': 'Zia', 'lname': 'Khan', 'city': 'Irvine',}
u1
# Out:
# {'name': 'Zia', 'lname': 'Khan', 'city': 'Irvine'}

# %%
u2 = {'fname': 'Ali', 'name': 'A', 'lname': 'Zaid'}
u2
# Out:
# {'name': 'Ali', 'fname': 'Zia A', 'lname': 'Zaid'}

# %%
s = [u1,u2]
s[1]
# Out:
# {'name': 'Ali', 'fname': 'Zia A', 'lname': 'Zaid'}

# %%
for _ in s:
    print(_['name'])
    print('**')
# Out:
# Zia
# **
# Ali
# **

# %%
u1['tel'] = 1234

# %%
u1
# Out:
# {'name': 'Zia', 'lname': 'Khan', 'city': 'Irvine', 'tel': 1234}

# %%
class student:

    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.email = first+"."+last+"@lf.com"

# %%
class student:

    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.email = first+"."+last+"@lf.com"

    def fullname(self):
        return "{} {}".format(self.first,self.last)

# %%
student_1 = student("Zia","Khan")

# %%
student_1.email
# Out:
# 'Zia.Khan@lf.com'

# %%
student_1.fullname()
# Out:
# 'Zia Khan'

# %% [markdown]
# # Restaurant

# %%
class restaurant:

    def __init__(self, restaurant_name , cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type


    def describe_restaurant(self):
        return "Restaurant name is {} and cuisine type is {}".format(self.restaurant_name,self.cuisine_type)

# %%
res_1 = restaurant('Mint', 'Pakistani')

# %%
res_1.describe_restaurant()
# Out:
# 'Restaurant name is Mint and cuisine type is Pakistani'

# %%
res_1.cuisine_type
# Out:
# 'Pakistani'
