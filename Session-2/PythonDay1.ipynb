# %% [markdown]
# # Heading
#
# ##### notes

# %%
print("Hello Data Scientist!")
# Out:
# Hello Data Scientist!

# %%
x = 10

if x>10:
  print("The number is greater than 10")
elif x==10:
  print("x is equal to 10")
else:
  print("x is less than 10")
# Out:
# x is equal to 10

# %%
age = 60

if age<2:
  print("Baby")
elif age<4:
  print("Toddler")
elif age<13:
  print("Kid")
elif age<20:
  print("Teenager")
elif age<65:
  print("Adult")
else:
  print("Senior")
# Out:
# Adult

# %%
integer = int(10.4)

print(integer)

if integer%2 == 1:
  print("Weird")
else:
  if 1 <= integer <=100:
    print("Not Weird")
  else:
    print("Weird")
# Out:
# 102
# Weird

# %%
integer = int(102.4)

print(integer)

if integer%2 == 1:
  print("Weird")
elif integer%2 ==0:
  if 1 <= integer <=100:
    print("Not Weird")
  else:
    print("Weird")
else:
  print("Number out of range")

# %%
import sys

try:
  number1 = float(input("Enter Number 1= "))
  number2 = float(input("Enter Number 2= "))

  print(type(number1))
  print(type(number2))

  _sum = number1 + number2
  print("The sum of the numbers is {}".format(_sum))

except Exception as err:
  print("Please enter a numeric value")
  print("Error", err)
  print(sys.exc_info())
# Out:
# Enter Number 1= 2o
# Please enter a numeric value
# Error could not convert string to float: '2o'
# (<class 'ValueError'>, ValueError("could not convert string to float: '2o'"), <traceback object at 0x7cab0255a100>)

# %%
_list = [1,2,'A','a',[1,'a'],(1,),1]

# %%
_list
# Out:
# [1, 2, 'A', 'a', [1, 'a'], (1,), 1]

# %%
city = ['Vancouver','Irvine','Houston','Toronto','Newport']

# %%
city
# Out:
# ['Vancouver', 'Irvine', 'Houston', 'Toronto', 'Newport']

# %%
sorted_list = sorted(city, reverse=True)

# %%
city
# Out:
# ['Vancouver', 'Irvine', 'Houston', 'Toronto', 'Newport']

# %%
sorted_list
# Out:
# ['Houston', 'Irvine', 'Newport', 'Toronto', 'Vancouver']

# %%
city.sort()

# %%
city
# Out:
# ['Houston', 'Irvine', 'Newport', 'Toronto', 'Vancouver']

# %%
sorted(city, reverse=True)
# Out:
# ['Vancouver', 'Toronto', 'Newport', 'Irvine', 'Houston']

# %%
city.reverse()

# %%
city
# Out:
# ['Vancouver', 'Toronto', 'Newport', 'Irvine', 'Houston']

# %%
cars = []

# %%
cars.append('Audi')

# %%
cars
# Out:
# ['Tesla', 'Ferrari', 'McLaren', 'Audi']

# %%
cars.insert(2, 'Mazda')

# %%
cars.pop(2)
# Out:
# 'Mazda'

# %%
cars.remove('Audi')

# %%
for i,v in enumerate(cars):
  print("Index is {} and Car is {}".format(i,v))
# Out:
# Index is 0 and Car is Tesla
# Index is 1 and Car is Ferrari
# Index is 2 and Car is McLaren
# Index is 3 and Car is Audi

# %%
buffet = ('Chicken','Beef','Shrimp','Fries','Salad')

# %%
type(buffet)
# Out:
# tuple

# %%
buffet[0] = 'Rice'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-cece7945534d> in <cell line: 1>()
# ----> 1 buffet[0] = 'Rice'
#
# TypeError: 'tuple' object does not support item assignment

# %%
buffet_list = list(buffet)

# %%
buffet_list
# Out:
# ['Chicken', 'Beef', 'Shrimp', 'Fries', 'Salad']

# %%
buffet_list[0] = 'Rice'
buffet_list
# Out:
# ['Rice', 'Beef', 'Shrimp', 'Fries', 'Salad']

# %%
buffet = tuple(buffet_list)

# %%
buffet
# Out:
# ('Rice', 'Beef', 'Shrimp', 'Fries', 'Salad')

# %%
for a,b in enumerate(buffet):
  print("Index is {} and Menu item is {}".format(a,b))
# Out:
# Index is 0 and Menu item is Rice
# Index is 1 and Menu item is Beef
# Index is 2 and Menu item is Shrimp
# Index is 3 and Menu item is Fries
# Index is 4 and Menu item is Salad

# %%
info = {'city': 'Vancouver', 'lname': 'Khan', 'name': 'Zia'}

# %%
info
# Out:
# {'city': 'Vancouver', 'lname': 'Khan', 'name': 'Zia'}

# %%
info.keys()
# Out:
# dict_keys(['city', 'lname', 'name'])

# %%
info.values()
# Out:
# dict_values(['Vancouver', 'Khan', 'Zia'])

# %%
info['name']
# Out:
# 'Zia'

# %%
info['email'] = 'zia@abc.com'

# %%
info
# Out:
# {'city': 'Vancouver', 'lname': 'Khan', 'name': 'Zee'}

# %%
info['name'] = 'Zee'

# %%
info.pop('email')
# Out:
# 'zia@abc.com'

# %%
info
# Out:
# {'city': 'Vancouver', 'lname': 'Khan', 'name': 'Zee'}

# %%
for k,v in info.items():
  print("Key is {} value is {}".format(k,v))
# Out:
# Key is city value is Vancouver
# Key is lname value is Khan
# Key is name value is Zee

# %%
for k in info.keys():
  print("Key is {} value is {}".format(k, info[k]))
# Out:
# Key is city value is Vancouver
# Key is lname value is Khan
# Key is name value is Zee

# %%
list(enumerate(info))
# Out:
# [(0, 'city'), (1, 'lname'), (2, 'name'), (3, 'cell')]

# %%
for i,v in enumerate(info):
  print(v)
# Out:
# city
# lname
# name
# cell

# %%
info['cell'] = 714

# %%
info
# Out:
# {'city': 'Vancouver', 'lname': 'Khan', 'name': 'Zee', 'cell': 714}

# %%
l = ['A','B',1,True, (3,4,5)]

# %%
for x in l:
  print(x)
# Out:
# A
# B
# 1
# True
# (3, 4, 5)

# %%
list(enumerate(l))
# Out:
# [(0, 'A'), (1, 'B'), (2, 1), (3, True), (4, (3, 4, 5))]

# %%
list(enumerate(l))[0]
# Out:
# (0, 'A')

# %%
[(1,3),]

# %%
s = ['orange','orange','apple']
t = ['apple','banana']

# %%
set(s)
# Out:
# {'apple', 'orange'}

# %%
set(t)
# Out:
# {'apple', 'banana'}

# %%
set(s) - set(t)
# Out:
# {'orange'}

# %%
set(t) - set(s)
# Out:
# {'banana'}

# %%
set(s) & set(t)
# Out:
# {'apple'}

# %%
set(s) | set(t)
# Out:
# {'apple', 'banana', 'orange'}

# %%
def hello(name):
  print("Hello Data Scientist!")

# %%
hello(name="Zia")
# Out:
# Hello Data Scientist!

# %%
hello()
# Out:
# Hello Data Scientist!

# %%
name = hello("Zia")
# Out:
# Hello Data Scientist!

# %%
def hello_return(name):
  return "Hello Data Scientist!"

# %%
hello_return("Zia")
# Out:
# 'Hello Data Scientist!'

# %%
hello("Zia")
# Out:
# Hello Data Scientist!

# %%
name

# %%
return_name = hello_return("Zia")

# %%
return_name
# Out:
# 'Hello Data Scientist!'

# %%
def _sum(number1,number2):
  return(number1+number2)

# %%
_sum(1,2)
# Out:
# 3

# %%
result = _sum(1,two)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-babf4e7956db> in <cell line: 1>()
# ----> 1 result = _sum(1,two)
#
# NameError: name 'two' is not defined

# %%
result
# Out:
# 3
